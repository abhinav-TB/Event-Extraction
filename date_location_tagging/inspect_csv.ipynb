# %%
from pandas import read_csv

# %%
df = read_csv('../outputs/allen_heidal_time_loc_and_date_filled_and_resolved.csv')

# %%
df
# Out:
#                        news_id  \
# 0     62f7ce2ed1eafd03bd6feb3a
# 1     62f7ce2ed1eafd03bd6feb3a
# 2     62f7ce2ed1eafd03bd6feb3a
# 3     62f7ce2ed1eafd03bd6feb3a
# 4     62f7ce2ed1eafd03bd6feb3a
# ...                        ...
# 2265  62f7ce2ed1eafd03bd6ff057
# 2266  62f7ce2ed1eafd03bd6ff057
# 2267  62f7ce2ed1eafd03bd6ff057
# 2268  62f7ce2ed1eafd03bd6ff057
# 2269  62f7ce2ed1eafd03bd6ff057
#
#                                              news_title  \
# 0             Ecotourism Is The Solution To Overtourism
# 1             Ecotourism Is The Solution To Overtourism
# 2             Ecotourism Is The Solution To Overtourism
# 3             Ecotourism Is The Solution To Overtourism
# 4             Ecotourism Is The Solution To Overtourism
# ...                                                 ...
# 2265  Yeddy To Be CM For 4th Time,Cong Says He Doesn...
# 2266  Yeddy To Be CM For 4th Time,Cong Says He Doesn...
# 2267  Yeddy To Be CM For 4th Time,Cong Says He Doesn...
# 2268  Yeddy To Be CM For 4th Time,Cong Says He Doesn...
# 2269  Yeddy To Be CM For 4th Time,Cong Says He Doesn...
#
#                                                   event location_prediction  \
# 0     Overtourism is a grave challenge that is harmi...                 NaN
# 1     Overtourism has been covered in media and publ...                 NaN
# 2     Overtourism is not only completely unsustainab...                 NaN
# 3     Policy responses to Overtourism are, in many c...                 NaN
# 4     Overtourism can negatively affect travelers’ s...                 NaN
# ...                                                 ...                 ...
# 2265  "BENGALURU —  Karnataka BJP President B S Yedd...           BENGALURU
# 2266  The state BJP leadership was awaiting "instruc...           BENGALURU
# 2267  A group of Karnataka BJP leaders, including Ja...           BENGALURU
# 2268  In BENGALURU —  Karnataka BJP President B S Ye...           BENGALURU
# 2269  "I submit that BENGALURU —  Karnataka BJP Pres...           BENGALURU
#
#      village district state  \
# 0        NaN      NaN   NaN
# 1        NaN      NaN   NaN
# 2        NaN      NaN   NaN
# 3        NaN      NaN   NaN
# 4        NaN      NaN   NaN
# ...      ...      ...   ...
# 2265     NaN      NaN   NaN
# 2266     NaN      NaN   NaN
# 2267     NaN      NaN   NaN
# 2268     NaN      NaN   NaN
# 2269     NaN      NaN   NaN
#
#                                         date_prediction event_type  \
# 0                                                    []     strike
# 1                                                    []     strike
# 2                                                    []     strike
# 3                                                    []     strike
# 4                                                    []     strike
# ...                                                 ...        ...
# 2265                                                 []      fight
# 2266                                                 []      fight
# 2267  [('2019-07-25', 'Thursday'), ('2019-07-25', 'T...      fight
# 2268                                                 []      fight
# 2269                                                 []      fight
#
#                                                     url
# 0     http://risingkashmir.com/news/ecotourism-is-th...
# 1     http://risingkashmir.com/news/ecotourism-is-th...
# 2     http://risingkashmir.com/news/ecotourism-is-th...
# 3     http://risingkashmir.com/news/ecotourism-is-th...
# 4     http://risingkashmir.com/news/ecotourism-is-th...
# ...                                                 ...
# 2265  https://kashmirobserver.net/2019/regional-news...
# 2266  https://kashmirobserver.net/2019/regional-news...
# 2267  https://kashmirobserver.net/2019/regional-news...
# 2268  https://kashmirobserver.net/2019/regional-news...
# 2269  https://kashmirobserver.net/2019/regional-news...
#
# [2270 rows x 10 columns]

# %%
df.isna().sum()
# Out:
# news_id                   0
# news_title                0
# event                     0
# location_prediction       0
# village                1547
# district               1547
# state                  1547
# date_prediction           0
# event_type                0
# url                       0
# dtype: int64

# %%
df.dropna(subset=['location_prediction'], inplace=True)

# %%
# save df to csv
df.to_csv('../outputs/allen_heidal_time_loc_and_date_filled_resolved_and_dropped.csv')
